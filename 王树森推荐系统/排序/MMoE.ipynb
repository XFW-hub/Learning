# %% [markdown]
# ## 多目标模型的改进

# %% [markdown]
# ![](1.jpg)

# %% [markdown]
# ![](2.jpg)

# %% [markdown]
# ### 极化现象

# %% [markdown]
# softmax输出值一个接近1，其余接近0

# %% [markdown]
# 解决方案：
#
# 在训练时，对softmax的输出使用dropout
#
# softmax输出的n个数值被mask的概率都是10%
