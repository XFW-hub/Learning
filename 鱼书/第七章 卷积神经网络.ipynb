# %% [markdown]
# ## 卷积层(Convolutional Layer)

# %% [markdown]
# ### 填充（Padding）

# %% [markdown]
# 在输入数据周围填入固定的数据（比如0），以此调整输出数据的形状。

# %% [markdown]
# ### 步幅

# %% [markdown]
# 应用滤波器的位置间隔称为步幅（stride）。
