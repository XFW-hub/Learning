# %% [markdown]
# ## 视频播放时长

# %% [markdown]
# ![](3.jpg)

# %% [markdown]
# ## 视频完播

# %% [markdown]
# ### 回归方法

# %% [markdown]
# ![](5.jpg)

# %% [markdown]
# ### 二元分类方法

# %% [markdown]
# ### 调整后融分

# %% [markdown]
# ![](6.jpg)
