# %% [markdown]
# ## GeoHash召回/同城召回——根据地理位置

# %% [markdown]
# geohash表示地图上的长方形区域，取回该地点最新的k篇优质笔记
#
# 这条召回通道没有个性化

# %% [markdown]
# ## 作者召回

# %% [markdown]
# 相似作者/有交互作者/关注作者

# %% [markdown]
# ## 缓存召回

# %% [markdown]
# 复用前n次推荐精排的结果
