# %% [markdown]
# ## 池化层

# %% [markdown]
# 步幅和窗口大小一般一致
#
# Max池化 在窗口中取出最大的元素

# %% [markdown]
# ### 池化层的特征

# %% [markdown]
# 1. 没有要学习的参数
# 2. 通道数不变
# 3. 对微小的位置变化具有鲁棒性

# %% [markdown]
# ## 卷积层和池化层的实现
