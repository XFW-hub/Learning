# %% [markdown]
# ## 用户画像

# %% [markdown]
# - 用户ID
# - 人口统计学属性：性别、年龄
# - 账号信息：新老、活跃度
# - 感兴趣的类目、关键词、品牌

# %% [markdown]
# ## 物品画像

# %% [markdown]
# - 物品ID
# - 发布时间
# - 经纬度编码、所在城市
# - 标题、类目、关健词语、品牌
# - 字数、图片数、视频清晰度、标签数
# - 内容信息量、图片美学

# %% [markdown]
# ## 用户统计特征

# %% [markdown]
# 曝光数、点击数、点赞数、收藏数
# 按照笔记图文/视频分桶
# 按照笔记类目分桶

# %% [markdown]
# ## 笔记统计特征

# %% [markdown]
# 曝光数、点击数、点赞数、收藏数
# 按照用户性别分桶、按照用户年龄分桶
# 作者特征：发布笔记数、粉丝数、消费指标

# %% [markdown]
# ## 场景特征

# %% [markdown]
# - 用户定位
# - 当前时刻
# - 是否是周末、是否是节假日
# - 手机品牌、手机型号、操作系统

# %% [markdown]
# ## 特征处理

# %% [markdown]
# 1. 离散特征：做embedding
# 2. 连续特征：做分桶、变成离散特征

# %% [markdown]
# ## 特征覆盖率

# %% [markdown]
# 特征无法覆盖100%样本

# %% [markdown]
# ## 数据服务
